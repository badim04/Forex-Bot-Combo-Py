# %%
#pip install pandas_ta

# %%
#pip install backtesting

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import pandas_ta as ta

# %%
dataF = yf.download("GBPUSD=X", start="2024-04-19", end="2024-06-11", interval='5m')
#dataF.iloc[:,:]
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
grid_distance = 0.007
midprice = dataF['Close'].median()
print(f"The median value of the 'close' column is: {midprice}")
# Out:
# The median value of the 'close' column is: 1.261805772781372

# %%
def generate_grid(midprice, grid_distance, grid_range):
    return (np.arange(midprice-grid_range, midprice+grid_range, grid_distance))

grid = generate_grid(midprice=midprice, grid_distance=grid_distance, grid_range=0.1)
grid
# Out:
# array([1.16180577, 1.16880577, 1.17580577, 1.18280577, 1.18980577,
#        1.19680577, 1.20380577, 1.21080577, 1.21780577, 1.22480577,
#        1.23180577, 1.23880577, 1.24580577, 1.25280577, 1.25980577,
#        1.26680577, 1.27380577, 1.28080577, 1.28780577, 1.29480577,
#        1.30180577, 1.30880577, 1.31580577, 1.32280577, 1.32980577,
#        1.33680577, 1.34380577, 1.35080577, 1.35780577])

# %%
signal = [0]*len(dataF)
i=0
for index, row in dataF.iterrows():
    for p in grid:
        if min(row.Low, row.High)<p and max(row.Low, row.High)>p:
            signal[i]=1
    i+=1

# %%
dataF["signal"]=signal
dataF[dataF["signal"]==1]
# Out:
#                                Open      High       Low     Close  Adj Close  \
# Datetime
# 2024-04-19 13:30:00+01:00  1.245470  1.246059  1.245470  1.246028   1.246028
# 2024-04-19 13:45:00+01:00  1.246152  1.246152  1.245795  1.245920   1.245920
# 2024-04-19 14:20:00+01:00  1.245159  1.245826  1.245159  1.245826   1.245826
# 2024-04-19 14:50:00+01:00  1.245687  1.245951  1.245687  1.245951   1.245951
# 2024-04-19 14:55:00+01:00  1.245920  1.245966  1.245764  1.245811   1.245811
# ...                             ...       ...       ...       ...        ...
# 2024-06-07 13:40:00+01:00  1.274454  1.274584  1.273739  1.273869   1.273869
# 2024-06-07 13:50:00+01:00  1.274389  1.274389  1.273626  1.273626   1.273626
# 2024-06-07 13:55:00+01:00  1.273691  1.274080  1.273610  1.273820   1.273820
# 2024-06-07 14:15:00+01:00  1.273042  1.273950  1.273042  1.273837   1.273837
# 2024-06-07 15:40:00+01:00  1.273561  1.274048  1.273561  1.273902   1.273902
#
#                            Volume  signal
# Datetime
# 2024-04-19 13:30:00+01:00       0       1
# 2024-04-19 13:45:00+01:00       0       1
# 2024-04-19 14:20:00+01:00       0       1
# 2024-04-19 14:50:00+01:00       0       1
# 2024-04-19 14:55:00+01:00       0       1
# ...                           ...     ...
# 2024-06-07 13:40:00+01:00       0       1
# 2024-06-07 13:50:00+01:00       0       1
# 2024-06-07 13:55:00+01:00       0       1
# 2024-06-07 14:15:00+01:00       0       1
# 2024-06-07 15:40:00+01:00       0       1
#
# [324 rows x 7 columns]

# %%
dfpl = dataF[:].copy()
def SIGNAL():
    return dfpl.signal
dfpl['ATR'] = ta.atr(high = dfpl.High, low = dfpl.Low, close = dfpl.Close, length = 16)
dfpl.dropna(inplace=True)

# %%
from backtesting import Strategy
from backtesting import Backtest
import backtesting

class MyStrat(Strategy):
    mysize = 50
    def init(self):
        super().init()
        self.signal1 = self.I(SIGNAL)

    def next(self):
        super().next()
        slatr = 1.5*grid_distance #5*self.data.ATR[-1]
        TPSLRatio = 0.5

        if self.signal1==1 and len(self.trades)<=10000:             
            sl1 = self.data.Close[-1] + slatr
            tp1 = self.data.Close[-1] - slatr*TPSLRatio
            self.sell(sl=sl1, tp=tp1, size=self.mysize)

            sl1 = self.data.Close[-1] - slatr
            tp1 = self.data.Close[-1] + slatr*TPSLRatio
            self.buy(sl=sl1, tp=tp1, size=self.mysize)

bt = Backtest(dfpl, MyStrat, cash=500, margin=1/10, hedging=True, exclusive_orders=False)
stat = bt.run()
stat
# Out:
# Start                     2024-04-19 01:20...
# End                       2024-06-10 23:55...
# Duration                     52 days 22:35:00
# Exposure Time [%]                   98.598933
# Equity Final [$]                   537.071263
# Equity Peak [$]                    542.363869
# Return [%]                           7.414253
# Buy & Hold Return [%]                2.429026
# Return (Ann.) [%]                   66.259277
# Volatility (Ann.) [%]               26.655425
# Sharpe Ratio                         2.485771
# Sortino Ratio                        7.402902
# Calmar Ratio                        13.668354
# Max. Drawdown [%]                   -4.847641
# Avg. Drawdown [%]                   -0.297274
# Max. Drawdown Duration       20 days 18:40:00
# Avg. Drawdown Duration        0 days 16:51:00
# # Trades                                  602
# Win Rate [%]                        74.750831
# Best Trade [%]                       0.728328
# Worst Trade [%]                     -1.038665
# Avg. Trade [%]                       0.095489
# Max. Trade Duration          18 days 10:15:00
# Avg. Trade Duration           3 days 10:09:00
# Profit Factor                        1.455454
# Expectancy [%]                        0.09708
# SQN                                  4.270256
# _strategy                             MyStrat
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %%
backtesting.set_bokeh_output(notebook=False)
bt.plot(show_legend=False, plot_width=None, plot_equity=True, plot_return=False, 
plot_pl=False, plot_volume=False, plot_drawdown=False, smooth_equity=False, relative_equity=True, 
superimpose=True, resample=False, reverse_indicators=False, open_browser=True)
# Out:
# Row(id='7159', ...)

# %%
stat._trades.sort_values(by="EntryBar").head(20)
# Out:
#     Size  EntryBar  ExitBar  EntryPrice  ExitPrice       PnL  ReturnPct  \
# 7    -50       147      186    1.246152   1.240772  0.269032   0.004318
# 14    50       147      357    1.246152   1.235528 -0.531205  -0.008526
# 6    -50       150      186    1.245749   1.240670  0.253965   0.004077
# 13    50       150      357    1.245749   1.235420 -0.516465  -0.008292
# 5    -50       157      186    1.246215   1.240576  0.281907   0.004524
# 12    50       157      357    1.246215   1.235326 -0.544407  -0.008737
# 4    -50       163      186    1.245920   1.240701  0.260950   0.004189
